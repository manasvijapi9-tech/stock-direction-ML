# %% [markdown]
# <a href="https://colab.research.google.com/github/manasvijapi9-tech/stock-direction-ML/blob/main/stock_direction_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/manasvijapi9-tech/stock-direction-ML.git
# %cd stock-direction-ML
# Out:
# Cloning into 'stock-direction-ML'...
# remote: Enumerating objects: 65, done.
# remote: Counting objects: 100% (65/65), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 65 (delta 34), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (65/65), 21.74 KiB | 10.87 MiB/s, done.
# Resolving deltas: 100% (34/34), done.
# /content/stock-direction-ML

# %%
# %cd /content/stock-direction-ML
# Out:
# /content/stock-direction-ML

# %%
# !ls
# Out:
# README.md  requirements.txt  src

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !pwd
# Out:
# /content/stock-direction-ML

# %%
# !python src/fetch_data.py
# Out:
# Fetching data for TCS.NS from 2025-01-01 to 2025-10-31 ...
# [*********************100%***********************]  1 of 1 completed
# Saved: data/TCS_NS_raw.csv

# %%
import pandas as pd

df = pd.read_csv("data/TCS_NS_raw.csv")
df["close"] = pd.to_numeric(df["close"], errors="coerce")
df.dropna(inplace=True)
df.to_csv("data/TCS_NS_raw_clean.csv", index=False)

print("Fixed → data/TCS_NS_raw_clean.csv")
# Out:
# Fixed → data/TCS_NS_raw_clean.csv

# %%
from src.indicators import add_all_indicators
import pandas as pd

df = pd.read_csv("data/TCS_NS_raw_clean.csv")
df2 = add_all_indicators(df)
df2.to_csv("data/data_with_indicators.csv", index=False)

print("Indicators added → data/data_with_indicators.csv")
# Out:
# Indicators added → data/data_with_indicators.csv

# %%
# !python src/prepare_data.py
# Out:
# Saved: data/X.csv, data/y.csv, data/full_dataset.csv

# %%
# !python src/train_model.py
# Out:
# Train samples: 149 Test samples: 38
#
# 📌 Logistic Regression Accuracy: 0.5789473684210527
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
# !python src/evaluate.py
# Out:
# Figure(700x600)
# Saved: plots/confusion_matrix.png
#
# Random Forest Accuracy: 0.5263
# Figure(800x500)
# Saved: plots/probability_distribution.png
#
# ✅ Evaluation complete.

# %%
# !python src/prepare_data.py
# Out:
# Saved: data/X.csv, data/y.csv, data/full_dataset.csv

# %%
# !python src/train_model.py
# Out:
# Train samples: 149 Test samples: 38
#
# 📌 Logistic Regression Accuracy: 0.5789473684210527
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
# !python src/evaluate.py
# Out:
# Figure(700x600)
# Saved: plots/confusion_matrix.png
#
# Random Forest Accuracy: 0.5263
# Figure(800x500)
# Saved: plots/probability_distribution.png
#
# ✅ Evaluation complete.

# %%
from IPython.display import Image, display
display(Image("plots/confusion_matrix.png"))

# %%
display(Image("plots/probability_distribution.png"))
